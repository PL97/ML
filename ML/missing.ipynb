# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../data/pre/MELBOURNE_HOUSE_PRICES_LESS.csv')

# %%
data.isnull().any()
# Out:
# Suburb           False
# Address          False
# Rooms            False
# Type             False
# Price             True
# Method           False
# SellerG          False
# Date             False
# Postcode         False
# Regionname       False
# Propertycount    False
# Distance         False
# CouncilArea      False
# dtype: bool

# %% [markdown]
# # drop column

# %%
missing_columns = [col for col in data.columns if data[col].isnull().any()]
print(missing_columns)
print(data.isnull().sum())
data[missing_columns].mean()
# Out:
# ['Price']
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price            14590
# Method               0
# SellerG              0
# Date                 0
# Postcode             0
# Regionname           0
# Propertycount        0
# Distance             0
# CouncilArea          0
# dtype: int64
# Price    997898.241488
# dtype: float64

# %%
data.drop(missing_columns, axis = 1)
# Out:
#                   Suburb                 Address  Rooms Type Method  \
# 0             Abbotsford           49 Lithgow St      3    h      S
# 1             Abbotsford           59A Turner St      3    h      S
# 2             Abbotsford           119B Yarra St      3    h      S
# 3             Aberfeldie              68 Vida St      3    h      S
# 4           Airport West        92 Clydesdale Rd      2    h      S
# 5           Airport West            4/32 Earl St      2    t      S
# 6           Airport West          3/74 Hawker St      2    u      S
# 7           Airport West       1/26 Highridge Cr      3    h     SP
# 8              Albanvale           1 Jackson Cct      6    h     PI
# 9            Albert Park             18 Mills St      3    h      S
# 10                Albion      3/15 Drummartin St      3    u      S
# 11                Albion          3A Kororoit St      4    h      S
# 12            Alphington            55 Fulham Rd      2    h      S
# ...

# %% [markdown]
# ## imputation

# %%
from sklearn.preprocessing import Imputer

# %%
# imputed_X_train = pd.DataFrame(Imputer.fit_transform(X = data, y = data[missing_columns]))
# print(imputed_X_train)
# data[data.isnull()] = data[missing_columns]
data.fillna(value=0).isnull().any()
# Out:
# Suburb           False
# Address          False
# Rooms            False
# Type             False
# Price            False
# Method           False
# SellerG          False
# Date             False
# Postcode         False
# Regionname       False
# Propertycount    False
# Distance         False
# CouncilArea      False
# dtype: bool

# %% [markdown]
# ## imputation with extension

# %%
missing_line = np.where(data.isnull())
# Out:
# nan

# %%
data['missing'] = False
data.loc[missing_line[0], 'missing'] = True
data.head()
# Out:
#          Suburb           Address  Rooms Type      Price Method   SellerG  \
# 0    Abbotsford     49 Lithgow St      3    h  1490000.0      S    Jellis
# 1    Abbotsford     59A Turner St      3    h  1220000.0      S  Marshall
# 2    Abbotsford     119B Yarra St      3    h  1420000.0      S    Nelson
# 3    Aberfeldie        68 Vida St      3    h  1515000.0      S     Barry
# 4  Airport West  92 Clydesdale Rd      2    h   670000.0      S    Nelson
#
#         Date  Postcode             Regionname  Propertycount  Distance  \
# 0  1/04/2017      3067  Northern Metropolitan           4019       3.0
# 1  1/04/2017      3067  Northern Metropolitan           4019       3.0
# 2  1/04/2017      3067  Northern Metropolitan           4019       3.0
# 3  1/04/2017      3040   Western Metropolitan           1543       7.5
# 4  1/04/2017      3042   Western Metropolitan           3464      10.4
#
#                   CouncilArea  missing
# 0          Yarra City Council    False
# ...

# %%
data.iloc[missing_line[0], :]
# Out:
#                  Suburb                Address  Rooms Type  Price Method  \
# 8             Albanvale          1 Jackson Cct      6    h    NaN     PI
# 15       Altona Meadows           57 Tatman Dr      4    h    NaN     SN
# 24            Ashburton              1 Pitt St      4    h    NaN      S
# 29              Attwood     46 Threadneedle St      4    h    NaN     SN
# 38         Balwyn North            12 Agnes Av      3    h    NaN     SP
# 42         Balwyn North             1 Kalka St      4    h    NaN     SP
# 48            Beaumaris       2/3 Hutchison Av      2    t    NaN     VB
# 54            Bentleigh             2 Smith St      2    h    NaN      S
# 56       Bentleigh East        7/646 Centre Rd      2    u    NaN      S
# 62           Black Rock         11b Ardoyne St      3    t    NaN      S
# 70      Blackburn South           111B Eley Rd      3    t    NaN     SN
# 74              Boronia         15 Lorikeet Ct      4    h    NaN     PN
# ...
